# %%
# import logistic regression
from  sklearn.linear_model  import  LogisticRegression
# import accuracy score
from  sklearn.metrics  import  accuracy_score
# import train_test_split
from  sklearn.model_selection  import  train_test_split
import pandas  as  pd
import numpy  as  np
import csv

# %%
# load data from csv file
df  =  pd.read_csv( 'train.csv' )

data = np.array(df.values)

# drop first column
data = data[:,1:]

# %%
# split data into X and y
X_train = data[:,:-1]
y_train = data[:,-1]

# %%
# create logistic regression model
model = LogisticRegression()

# fit model
model.fit(X_train, y_train)

# open test data
df_test = pd.read_csv( 'test.csv' )

# convert to numpy array
data_test = np.array(df_test.values)

# drop first column
data_test = data_test[:,1:]

X_test = data_test

# predict
y_pred = model.predict(X_test)

print(y_pred)

# save predictions to csv file
with open ( 'submission.csv' ,  'w' , newline= '' )  as  file:
    writer = csv.writer(file)
    writer.writerow([ "ID" ,  "Category" ])
    for i in range(len(y_pred)):
        writer.writerow([i, y_pred[i]])
# Out:
# /opt/homebrew/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ['Leeche_Raw' 'Orange_Raw' 'Pomengranate_Ripe' 'Strawberry_Raw'
#  'Orange_Ripe' 'Banana_Ripe' 'Coconut_Ripe' 'Apple_Ripe' 'Coconut_Ripe'
#  'Coconut_Ripe' 'Strawberry_Ripe' 'Banana_Ripe' 'Mango_Raw' 'Papaya_Raw'
#  'Guava_Ripe' 'Leeche_Ripe' 'Orange_Raw' 'Banana_Raw' 'Mango_Ripe'
#  'Mango_Raw' 'Guava_Raw' 'Banana_Ripe' 'Orange_Ripe' 'Pomengranate_Raw'
#  'Orange_Raw' 'Strawberry_Ripe' 'Apple_Raw' 'Orange_Ripe' 'Coconut_Ripe'
#  'Orange_Ripe' 'Banana_Ripe' 'Apple_Ripe' 'Leeche_Raw' 'Banana_Raw'
#  'Coconut_Raw' 'Coconut_Raw' 'Apple_Ripe' 'Orange_Raw' 'Mango_Raw'
#  'Pomengranate_Ripe' 'Guava_Raw' 'Papaya_Raw' 'Leeche_Raw' 'Papaya_Ripe'
#  'Leeche_Raw' 'Apple_Ripe' 'Leeche_Raw' 'Apple_Ripe' 'Banana_Ripe'
#  'Coconut_Ripe' 'Papaya_Raw' 'Mango_Ripe' 'Mango_Raw' 'Mango_Ripe'
#  'Apple_Ripe' 'Leeche_Ripe' 'Mango_Ripe' 'Mango_Raw' 'Coconut_Raw'
#  'Strawberry_Ripe' 'Banana_Ripe' 'Guava_Raw' 'Apple_Raw'
#  'Pomengranate_Raw' 'Strawberry_Raw' 'Apple_Raw' 'Mango_Raw' 'Guava_Raw'
#  'Guava_Raw' 'Pomengranate_Raw' 'Guava_Ripe' 'Strawberry_Ripe'
#  'Coconut_Raw' 'Papaya_Ripe' 'Coconut_Raw' 'Guava_Ripe' 'Coconut_Ripe'
#  'Papaya_Ripe' 'Banana_Raw' 'Papaya_Raw' 'Mango_Raw' 'Apple_Raw'
#  'Apple_Ripe' 'Coconut_Ripe' 'Pomengranate_Raw' 'Leeche_Ripe' 'Mango_Raw'
#  'Mango_Ripe' 'Banana_Ripe' 'Orange_Raw' 'Pomengranate_Raw' 'Papaya_Ripe'
#  'Pomengranate_Raw' 'Apple_Ripe' 'Mango_Ripe' 'Apple_Raw' 'Leeche_Raw'
#  'Papaya_Ripe' 'Banana_Ripe' 'Pomengranate_Raw' 'Papaya_Ripe'
#  'Orange_Ripe' 'Pomengranate_Raw' 'Papaya_Raw' 'Orange_Ripe' 'Apple_Ripe'
#  'Apple_Raw' 'Mango_Ripe' 'Apple_Ripe' 'Strawberry_Ripe' 'Coconut_Raw'
#  'Strawberry_Raw' 'Strawberry_Raw' 'Mango_Ripe' 'Mango_Ripe' 'Papaya_Ripe'
#  'Strawberry_Raw' 'Papaya_Ripe' 'Pomengranate_Ripe' 'Guava_Raw'
#  'Apple_Ripe' 'Papaya_Ripe' 'Coconut_Ripe' 'Apple_Raw' 'Guava_Raw'
#  'Orange_Ripe' 'Orange_Ripe' 'Apple_Ripe' 'Apple_Ripe' 'Strawberry_Ripe'
#  'Coconut_Ripe' 'Orange_Raw' 'Strawberry_Raw' 'Papaya_Raw'
#  'Strawberry_Raw' 'Leeche_Raw' 'Banana_Ripe' 'Guava_Raw' 'Mango_Ripe'
#  'Apple_Ripe' 'Coconut_Raw' 'Mango_Raw' 'Mango_Raw' 'Apple_Raw'
#  'Strawberry_Raw' 'Leeche_Raw' 'Pomengranate_Raw' 'Banana_Ripe'
#  'Pomengranate_Ripe' 'Strawberry_Raw' 'Mango_Ripe' 'Leeche_Raw'
#  'Strawberry_Ripe' 'Pomengranate_Ripe' 'Mango_Raw' 'Pomengranate_Raw'
#  'Strawberry_Ripe' 'Orange_Ripe' 'Orange_Ripe' 'Strawberry_Raw'
#  'Coconut_Ripe' 'Coconut_Ripe' 'Leeche_Ripe' 'Banana_Ripe' 'Mango_Raw'
#  'Mango_Ripe' 'Orange_Ripe' 'Apple_Raw' 'Apple_Raw' 'Orange_Raw'
#  'Banana_Raw' 'Leeche_Ripe' 'Apple_Ripe' 'Banana_Ripe' 'Guava_Ripe'
#  'Mango_Raw' 'Pomengranate_Ripe' 'Coconut_Raw' 'Pomengranate_Raw'
#  'Strawberry_Raw' 'Banana_Ripe' 'Coconut_Ripe' 'Banana_Raw' 'Papaya_Raw'
#  'Leeche_Ripe' 'Banana_Ripe' 'Banana_Ripe' 'Leeche_Ripe' 'Coconut_Raw'
#  'Guava_Raw' 'Guava_Ripe' 'Mango_Ripe' 'Coconut_Raw' 'Apple_Ripe'
#  'Mango_Raw' 'Banana_Raw' 'Apple_Ripe' 'Banana_Raw' 'Papaya_Raw'
#  'Strawberry_Ripe' 'Strawberry_Ripe' 'Apple_Raw' 'Leeche_Ripe'
#  'Papaya_Ripe' 'Guava_Raw' 'Banana_Raw' 'Leeche_Raw' 'Banana_Ripe'
#  'Banana_Ripe' 'Leeche_Ripe' 'Strawberry_Ripe' 'Strawberry_Raw'
#  'Pomengranate_Ripe' 'Strawberry_Ripe' 'Pomengranate_Ripe' 'Banana_Raw'
#  'Apple_Raw' 'Mango_Raw' 'Strawberry_Raw' 'Apple_Ripe' 'Mango_Raw'
#  'Coconut_Ripe' 'Coconut_Ripe' 'Guava_Ripe' 'Mango_Ripe' 'Apple_Ripe'
#  'Strawberry_Ripe' 'Pomengranate_Raw' 'Strawberry_Ripe' 'Strawberry_Raw'
#  'Mango_Raw' 'Papaya_Ripe' 'Strawberry_Ripe' 'Papaya_Raw' 'Papaya_Raw'
#  'Guava_Raw' 'Pomengranate_Raw' 'Mango_Ripe' 'Coconut_Ripe' 'Guava_Ripe'
#  'Orange_Raw' 'Coconut_Ripe' 'Pomengranate_Ripe' 'Leeche_Raw'
#  'Coconut_Raw' 'Banana_Ripe' 'Apple_Ripe' 'Banana_Ripe' 'Guava_Raw'
#  'Papaya_Raw' 'Apple_Raw' 'Banana_Ripe' 'Leeche_Ripe' 'Apple_Raw'
#  'Apple_Ripe' 'Apple_Ripe' 'Guava_Ripe' 'Orange_Raw' 'Banana_Raw'
#  'Papaya_Ripe' 'Coconut_Raw' 'Leeche_Ripe' 'Mango_Raw' 'Apple_Raw'
#  'Pomengranate_Raw' 'Mango_Raw' 'Mango_Raw' 'Banana_Ripe' 'Orange_Ripe'
#  'Coconut_Ripe' 'Papaya_Ripe' 'Leeche_Raw' 'Papaya_Raw' 'Mango_Ripe'
#  'Orange_Raw' 'Coconut_Raw' 'Papaya_Ripe' 'Banana_Ripe' 'Strawberry_Ripe'
#  'Pomengranate_Raw' 'Leeche_Ripe' 'Apple_Ripe' 'Banana_Ripe'
#  'Strawberry_Ripe' 'Apple_Ripe' 'Apple_Raw' 'Papaya_Ripe' 'Papaya_Ripe'
#  'Strawberry_Ripe' 'Strawberry_Ripe' 'Banana_Raw' 'Apple_Raw' 'Mango_Ripe'
#  'Papaya_Raw' 'Mango_Raw' 'Guava_Ripe' 'Strawberry_Ripe' 'Leeche_Ripe'
#  'Coconut_Raw' 'Apple_Raw' 'Leeche_Ripe' 'Pomengranate_Raw' 'Guava_Ripe'
#  'Guava_Raw' 'Leeche_Raw' 'Pomengranate_Ripe' 'Pomengranate_Ripe'
#  'Strawberry_Ripe' 'Banana_Ripe' 'Apple_Ripe' 'Mango_Raw' 'Leeche_Ripe'
#  'Pomengranate_Raw' 'Guava_Ripe' 'Papaya_Ripe' 'Mango_Raw' 'Guava_Ripe'
#  'Strawberry_Ripe' 'Papaya_Ripe' 'Guava_Ripe' 'Pomengranate_Ripe'
#  'Papaya_Raw' 'Strawberry_Raw' 'Strawberry_Raw' 'Guava_Raw'
#  'Strawberry_Raw' 'Pomengranate_Ripe' 'Leeche_Ripe' 'Orange_Ripe'
#  'Guava_Raw' 'Strawberry_Ripe' 'Coconut_Raw' 'Mango_Raw'
#  'Pomengranate_Ripe' 'Coconut_Ripe' 'Pomengranate_Ripe' 'Coconut_Raw'
#  'Strawberry_Ripe' 'Pomengranate_Raw' 'Leeche_Raw' 'Apple_Raw' 'Mango_Raw'
#  'Apple_Raw' 'Guava_Ripe' 'Papaya_Raw' 'Banana_Raw' 'Papaya_Raw'
#  'Banana_Raw' 'Strawberry_Ripe' 'Pomengranate_Ripe' 'Coconut_Raw'
#  'Mango_Ripe' 'Pomengranate_Raw' 'Papaya_Raw' 'Guava_Ripe'
#  'Strawberry_Ripe' 'Apple_Raw' 'Coconut_Ripe' 'Strawberry_Raw'
#  'Apple_Ripe' 'Apple_Raw' 'Pomengranate_Raw' 'Strawberry_Ripe' 'Apple_Raw'
#  'Apple_Raw' 'Apple_Raw' 'Pomengranate_Raw' 'Leeche_Ripe'
#  'Pomengranate_Ripe' 'Strawberry_Ripe' 'Banana_Raw' 'Orange_Raw'
#  'Guava_Raw' 'Guava_Ripe' 'Coconut_Ripe' 'Papaya_Ripe' 'Papaya_Raw'
#  'Coconut_Ripe' 'Guava_Raw' 'Banana_Ripe' 'Mango_Ripe' 'Mango_Raw'
#  'Coconut_Raw' 'Guava_Raw' 'Pomengranate_Raw' 'Leeche_Ripe' 'Banana_Raw'
#  'Orange_Raw' 'Orange_Ripe' 'Banana_Raw' 'Banana_Raw' 'Mango_Ripe'
#  'Apple_Ripe' 'Guava_Raw' 'Banana_Ripe' 'Leeche_Raw' 'Banana_Raw'
#  'Papaya_Ripe' 'Pomengranate_Raw' 'Apple_Ripe' 'Banana_Ripe' 'Orange_Ripe'
#  'Apple_Ripe' 'Leeche_Raw' 'Pomengranate_Ripe' 'Strawberry_Ripe'
#  'Coconut_Ripe' 'Banana_Ripe' 'Mango_Raw' 'Mango_Raw' 'Orange_Ripe'
#  'Apple_Ripe' 'Banana_Ripe' 'Apple_Raw' 'Strawberry_Raw']
